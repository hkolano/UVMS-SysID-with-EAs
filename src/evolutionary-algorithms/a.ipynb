# %%
def get_fit(x):
    return x+10

list_ = list(range(10))

fits = map(get_fit, list_)

# %%
for fit in fits:
    print(fit)

# %%
import csv

# %%
dir = "/home/gonzaeve/UVMS-SysID-with-EAs/src/evolutionary-algorithms/config/config_v1.yaml"

# %%
with open(dir, 'r') as file:
    config = yaml.safe_load(file)

print(config)
# Out:
# {'save_options': {'save_dir': '~/hpc-share/uvms/preliminary/trial_0'}, 'ea_parameters': {'number_of_generations': 5000, 'mutation_probability': 0.1, 'crossover_probability': 0.5, 'population_size': 50, 'trajectory_names': ['_alt_001-0', '_alt_001-1', '_alt_001-2', '_alt_002-0', '_alt_002-1', '_alt_008-0', '_alt_008-1', '_alt_008-2', '_alt_009-0', '_alt_009-1', '_alt_011-0', '_alt_011-1', '_alt_011-2'], 'start_with_default_params': True}, 'default_dynamic_params': {'cob_vec_dict': {'vehicle': [0.0074, 0.0, 0.02], 'foamL': [0.0, 0.11, 0.027], 'foamR': [0.0, -0.11, 0.027], 'shoulder': [-0.001, -0.003, 0.032], 'upperarm': [0.073, 0.0, -0.002], 'elbow': [0.003, 0.001, -0.017], 'wrist': [0.0, 0.0, -0.098], 'jaw': [0.0, 0.0, 0.0]}, 'buoyancy_mag_dict': {'vehicle': 128.33442000000002, 'foamL': 8.46, 'foamR': 8.86, 'shoulder': 0.17605026, 'upperarm': 1.9854557100000003, 'armbase': 1.97567514, 'jaw': 0.19561140000000005, 'wrist': 1.5159883500000002, 'elbow': 0.24451425000000004}, 'com_vec_dict
# ...

# %%
help(yaml.safe_load)
# Out:
# Help on function safe_load in module yaml:
#
# safe_load(stream)
#     Parse the first YAML document in a stream
#     and produce the corresponding Python object.
#
#     Resolve only basic YAML tags. This is known
#     to be safe for untrusted input.
